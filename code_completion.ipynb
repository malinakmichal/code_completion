# %%
import pandas as pd
from script_completion import print_results

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#                                              preffix  \
# 0  import pandas as pd\nimport numpy as np\nimpor...
# 1  import pandas as pd\nimport numpy as np\nimpor...
# 2  import pandas as pd\nimport numpy as np\nimpor...
# 3  import pandas as pd\nimport numpy as np\nimpor...
# 4  import pandas as pd\nimport numpy as np\nimpor...
#
#                                               suffix  \
# 0      def forward(self, x):\n        x = x.flatt...
# 1              x = self.conv1_drop(x)\n        x ...
# 2  model_conv = ConvNetwork(training_loader, vali...
# 3          x = F.relu(self.fc2(x))\n        x = s...
# 4  \n\nmodel_dense = DenseNetwork(training_loader...
#
#                            label                                  result  \
# 0                # dopredny chod                   def forward(self, x):
# 1          if self.dropout_prob:          x = F.relu(self.conv1_drop(x))
# 2                            NaN                                     NaN
# ...

# %%
def show_data(data):
    print(f"\tPrefix:\n{data['preffix']}\n\n\tFill here\n\tActual code:\n{data['label']}\n\tGenerated code:\n{data['result']}\n\nSuffix:\n{data['suffix']}")

# %%
show_data(data.iloc[0])
# Out:
# 	Prefix:
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from torch import nn
# import torch.nn.functional as F
# import torch.utils.data
# import matplotlib.pyplot as plt
# import Network
#
# data = pd.read_csv("train.csv")
#
# label = data['label']
# img = data.drop('label', axis=1)
# img_tensor = np.array(img).reshape(-1, 1, 32, 32)
#
# dataset = torch.utils.data.TensorDataset(torch.tensor(img_tensor, dtype = torch.float).to("cuda"), torch.tensor(label, dtype = torch.long).to("cuda"))
# generator = torch.Generator().manual_seed(17)
# train_data, val_data, test_data = torch.utils.data.random_split(dataset, [0.7, 0.15, 0.15], generator)
#
# training_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
# validation_loader = torch.utils.data.DataLoader(val_data, batch_size=128, shuffle=False)
# testing_loader = torch.utils.data.DataLoader(test_data, batch_size=128, shuffle=False)
#
#
# class DenseNetwork(Network):
# ...

# %% [markdown]
# wrong code - duplicates a line that is used afterwards

# %%
data.loc[0, "correct_code"] = False

# %%
show_data(data.iloc[1])
# Out:
# 	Prefix:
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from torch import nn
# import torch.nn.functional as F
# import torch.utils.data
# import matplotlib.pyplot as plt
# import Network
#
# data = pd.read_csv("train.csv")
#
# label = data['label']
# img = data.drop('label', axis=1)
# img_tensor = np.array(img).reshape(-1, 1, 32, 32)
#
# dataset = torch.utils.data.TensorDataset(torch.tensor(img_tensor, dtype = torch.float).to("cuda"), torch.tensor(label, dtype = torch.long).to("cuda"))
# generator = torch.Generator().manual_seed(17)
# train_data, val_data, test_data = torch.utils.data.random_split(dataset, [0.7, 0.15, 0.15], generator)
#
# training_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
# validation_loader = torch.utils.data.DataLoader(val_data, batch_size=128, shuffle=False)
# testing_loader = torch.utils.data.DataLoader(test_data, batch_size=128, shuffle=False)
#
#
# class DenseNetwork(Network):
# ...

# %% [markdown]
# wrong code - applies relu, where it should not have been

# %%
data.loc[1, "correct_code"] = False

# %%
show_data(data.iloc[2])
# Out:
# 	Prefix:
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from torch import nn
# import torch.nn.functional as F
# import torch.utils.data
# import matplotlib.pyplot as plt
# import Network
#
# data = pd.read_csv("train.csv")
#
# label = data['label']
# img = data.drop('label', axis=1)
# img_tensor = np.array(img).reshape(-1, 1, 32, 32)
#
# dataset = torch.utils.data.TensorDataset(torch.tensor(img_tensor, dtype = torch.float).to("cuda"), torch.tensor(label, dtype = torch.long).to("cuda"))
# generator = torch.Generator().manual_seed(17)
# train_data, val_data, test_data = torch.utils.data.random_split(dataset, [0.7, 0.15, 0.15], generator)
#
# training_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
# validation_loader = torch.utils.data.DataLoader(val_data, batch_size=128, shuffle=False)
# testing_loader = torch.utils.data.DataLoader(test_data, batch_size=128, shuffle=False)
#
#
# class DenseNetwork(Network):
# ...

# %% [markdown]
# correct code - empty line

# %%
data.loc[2, "correct_code"] = True

# %%
show_data(data.iloc[3])
# Out:
# 	Prefix:
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from torch import nn
# import torch.nn.functional as F
# import torch.utils.data
# import matplotlib.pyplot as plt
# import Network
#
# data = pd.read_csv("train.csv")
#
# label = data['label']
# img = data.drop('label', axis=1)
# img_tensor = np.array(img).reshape(-1, 1, 32, 32)
#
# dataset = torch.utils.data.TensorDataset(torch.tensor(img_tensor, dtype = torch.float).to("cuda"), torch.tensor(label, dtype = torch.long).to("cuda"))
# generator = torch.Generator().manual_seed(17)
# train_data, val_data, test_data = torch.utils.data.random_split(dataset, [0.7, 0.15, 0.15], generator)
#
# training_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
# validation_loader = torch.utils.data.DataLoader(val_data, batch_size=128, shuffle=False)
# testing_loader = torch.utils.data.DataLoader(test_data, batch_size=128, shuffle=False)
#
#
# class DenseNetwork(Network):
# ...

# %% [markdown]
# correct code - exact match

# %%
data.loc[3, "correct_code"] = True

# %%
show_data(data.iloc[4])
# Out:
# 	Prefix:
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from torch import nn
# import torch.nn.functional as F
# import torch.utils.data
# import matplotlib.pyplot as plt
# import Network
#
# data = pd.read_csv("train.csv")
#
# label = data['label']
# img = data.drop('label', axis=1)
# img_tensor = np.array(img).reshape(-1, 1, 32, 32)
#
# dataset = torch.utils.data.TensorDataset(torch.tensor(img_tensor, dtype = torch.float).to("cuda"), torch.tensor(label, dtype = torch.long).to("cuda"))
# generator = torch.Generator().manual_seed(17)
# train_data, val_data, test_data = torch.utils.data.random_split(dataset, [0.7, 0.15, 0.15], generator)
#
# training_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
# validation_loader = torch.utils.data.DataLoader(val_data, batch_size=128, shuffle=False)
# testing_loader = torch.utils.data.DataLoader(test_data, batch_size=128, shuffle=False)
#
#
# class DenseNetwork(Network):
# ...

# %% [markdown]
# correct code - empty line

# %%
data.loc[4, "correct_code"] = True

# %%
show_data(data.iloc[5])
# Out:
# 	Prefix:
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from torch import nn
# import torch.nn.functional as F
# import torch.utils.data
# import matplotlib.pyplot as plt
# import Network
#
# data = pd.read_csv("train.csv")
#
# label = data['label']
# img = data.drop('label', axis=1)
# img_tensor = np.array(img).reshape(-1, 1, 32, 32)
#
# dataset = torch.utils.data.TensorDataset(torch.tensor(img_tensor, dtype = torch.float).to("cuda"), torch.tensor(label, dtype = torch.long).to("cuda"))
# generator = torch.Generator().manual_seed(17)
# train_data, val_data, test_data = torch.utils.data.random_split(dataset, [0.7, 0.15, 0.15], generator)
#
# training_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
# validation_loader = torch.utils.data.DataLoader(val_data, batch_size=128, shuffle=False)
# testing_loader = torch.utils.data.DataLoader(test_data, batch_size=128, shuffle=False)
#
#
# class DenseNetwork(Network):
# ...

# %% [markdown]
# correct code - empty line

# %%
data.loc[5, "correct_code"] = True

# %%
show_data(data.iloc[6])
# Out:
# 	Prefix:
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
#
# 	Fill here
# 	Actual code:
# from torch import nn
# 	Generated code:
# import torch
#
# Suffix:
# import torch.nn.functional as F
# import torch.utils.data
# import matplotlib.pyplot as plt
# import Network
#
# data = pd.read_csv("train.csv")
#
# label = data['label']
# img = data.drop('label', axis=1)
# img_tensor = np.array(img).reshape(-1, 1, 32, 32)
#
# dataset = torch.utils.data.TensorDataset(torch.tensor(img_tensor, dtype = torch.float).to("cuda"), torch.tensor(label, dtype = torch.long).to("cuda"))
# generator = torch.Generator().manual_seed(17)
# train_data, val_data, test_data = torch.utils.data.random_split(dataset, [0.7, 0.15, 0.15], generator)
#
# training_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
# validation_loader = torch.utils.data.DataLoader(val_data, batch_size=128, shuffle=False)
# ...

# %% [markdown]
# almost correct - importing correct library, but the code still will not work

# %%
data.loc[6, "correct_code"] = False

# %%
show_data(data.iloc[7])
# Out:
# 	Prefix:
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from torch import nn
# import torch.nn.functional as F
# import torch.utils.data
# import matplotlib.pyplot as plt
# import Network
#
# data = pd.read_csv("train.csv")
#
# label = data['label']
# img = data.drop('label', axis=1)
# img_tensor = np.array(img).reshape(-1, 1, 32, 32)
#
# dataset = torch.utils.data.TensorDataset(torch.tensor(img_tensor, dtype = torch.float).to("cuda"), torch.tensor(label, dtype = torch.long).to("cuda"))
# generator = torch.Generator().manual_seed(17)
# train_data, val_data, test_data = torch.utils.data.random_split(dataset, [0.7, 0.15, 0.15], generator)
#
# training_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
# validation_loader = torch.utils.data.DataLoader(val_data, batch_size=128, shuffle=False)
# testing_loader = torch.utils.data.DataLoader(test_data, batch_size=128, shuffle=False)
#
#
# class DenseNetwork(Network):
# ...

# %% [markdown]
# correct code - empty line

# %%
data.loc[7, "correct_code"] = True

# %%
show_data(data.iloc[8])
# Out:
# 	Prefix:
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_absolute_error, mean_squared_error
# import math
# import pandas as pd
# from sklearn.linear_model import Ridge
#
# def get_model(data):
#     y = data['days'].dt.total_seconds() / 60
#
# 	Fill here
# 	Actual code:
#     X = data.drop(columns='days')
# 	Generated code:
#     X = data['days'].dt.total_seconds() / 60
#
# Suffix:
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#     model = Ridge().fit(X_train, y_train)
#
#     y_pred = model.predict(X_test)
#     acc = mean_absolute_error(y_pred, y_test)
#     coef = model.coef_
#     print("Acc:", acc)
#     print("Coefs:", coef)
#
# if __name__ == "__main__":
#     interested = pd.read_csv("data.csv")
#     get_model(interested)

# %% [markdown]
# wrong code - selecting opposite columns from the dataset

# %%
data.loc[8, "correct_code"] = False

# %%
show_data(data.iloc[9])
# Out:
# 	Prefix:
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_absolute_error, mean_squared_error
# import math
# import pandas as pd
# from sklearn.linear_model import Ridge
#
# 	Fill here
# 	Actual code:
# nan
# 	Generated code:
# nan
#
# Suffix:
# def get_model(data):
#     y = data['days'].dt.total_seconds() / 60
#     X = data.drop(columns='days')
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#     model = Ridge().fit(X_train, y_train)
#
#     y_pred = model.predict(X_test)
#     acc = mean_absolute_error(y_pred, y_test)
#     coef = model.coef_
#     print("Acc:", acc)
#     print("Coefs:", coef)
#
# if __name__ == "__main__":
#     interested = pd.read_csv("data.csv")
#     get_model(interested)

# %% [markdown]
# correct code - empty line

# %%
data.loc[9, "correct_code"] = True

# %%
show_data(data.iloc[10])
# Out:
# 	Prefix:
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_absolute_error, mean_squared_error
# import math
# import pandas as pd
# from sklearn.linear_model import Ridge
#
# def get_model(data):
#     y = data['days'].dt.total_seconds() / 60
#
# 	Fill here
# 	Actual code:
#     X = data.drop(columns='days')
# 	Generated code:
#     X = data['days'].dt.total_seconds() / 60
#
# Suffix:
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#     model = Ridge().fit(X_train, y_train)
#
#     y_pred = model.predict(X_test)
#     acc = mean_absolute_error(y_pred, y_test)
#     coef = model.coef_
#     print("Acc:", acc)
#     print("Coefs:", coef)
#
# if __name__ == "__main__":
#     interested = pd.read_csv("data.csv")
#     get_model(interested)

# %% [markdown]
# wrong code - selecting opposite columns

# %%
data.loc[10, "correct_code"] = False

# %%
show_data(data.iloc[11])
# Out:
# 	Prefix:
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_absolute_error, mean_squared_error
#
# 	Fill here
# 	Actual code:
# import math
# 	Generated code:
# from sklearn.metrics <|endoftext|>
#
# Suffix:
# import pandas as pd
# from sklearn.linear_model import Ridge
#
# def get_model(data):
#     y = data['days'].dt.total_seconds() / 60
#     X = data.drop(columns='days')
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#     model = Ridge().fit(X_train, y_train)
#
#     y_pred = model.predict(X_test)
#     acc = mean_absolute_error(y_pred, y_test)
#     coef = model.coef_
#     print("Acc:", acc)
#     print("Coefs:", coef)
#
# if __name__ == "__main__":
#     interested = pd.read_csv("data.csv")
#     get_model(interested)

# %% [markdown]
# wrong code - importing wrong library

# %%
data.loc[11, "correct_code"] = False

# %%
show_data(data.iloc[12])
# Out:
# 	Prefix:
# from sklearn.linear_model import LinearRegression
#
# 	Fill here
# 	Actual code:
# from sklearn.model_selection import train_test_split
# 	Generated code:
# nan
#
# Suffix:
# from sklearn.metrics import mean_absolute_error, mean_squared_error
# import math
# import pandas as pd
# from sklearn.linear_model import Ridge
#
# def get_model(data):
#     y = data['days'].dt.total_seconds() / 60
#     X = data.drop(columns='days')
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#     model = Ridge().fit(X_train, y_train)
#
#     y_pred = model.predict(X_test)
#     acc = mean_absolute_error(y_pred, y_test)
#     coef = model.coef_
#     print("Acc:", acc)
#     print("Coefs:", coef)
#
# if __name__ == "__main__":
#     interested = pd.read_csv("data.csv")
#     get_model(interested)

# %% [markdown]
# wrong code - wrong library selected

# %%
data.loc[12, "correct_code"] = False

# %%
show_data(data.iloc[13])
# Out:
# 	Prefix:
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_absolute_error, mean_squared_error
# import math
# import pandas as pd
# from sklearn.linear_model import Ridge
#
#
# 	Fill here
# 	Actual code:
# def get_model(data):
# 	Generated code:
# nan
#
# Suffix:
#     y = data['days'].dt.total_seconds() / 60
#     X = data.drop(columns='days')
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#     model = Ridge().fit(X_train, y_train)
#
#     y_pred = model.predict(X_test)
#     acc = mean_absolute_error(y_pred, y_test)
#     coef = model.coef_
#     print("Acc:", acc)
#     print("Coefs:", coef)
#
# if __name__ == "__main__":
#     interested = pd.read_csv("data.csv")
#     get_model(interested)

# %% [markdown]
# wrong code - no start of a function definition generated

# %%
data.loc[13, "correct_code"] = False

# %%
show_data(data.iloc[14])
# Out:
# 	Prefix:
# from sklearn.linear_model import LinearRegression
#
# 	Fill here
# 	Actual code:
# from sklearn.model_selection import train_test_split
# 	Generated code:
# nan
#
# Suffix:
# from sklearn.metrics import mean_absolute_error, mean_squared_error
# import math
# import pandas as pd
# from sklearn.linear_model import Ridge
#
# def get_model(data):
#     y = data['days'].dt.total_seconds() / 60
#     X = data.drop(columns='days')
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#     model = Ridge().fit(X_train, y_train)
#
#     y_pred = model.predict(X_test)
#     acc = mean_absolute_error(y_pred, y_test)
#     coef = model.coef_
#     print("Acc:", acc)
#     print("Coefs:", coef)
#
# if __name__ == "__main__":
#     interested = pd.read_csv("data.csv")
#     get_model(interested)

# %% [markdown]
# wrong code - library not imported

# %%
data.loc[14, "correct_code"] = False

# %%
show_data(data.iloc[15])
# Out:
# 	Prefix:
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split
#
# 	Fill here
# 	Actual code:
# from sklearn.metrics import mean_absolute_error, mean_squared_error
# 	Generated code:
# from sklearn.metrics <|endoftext|>
#
# Suffix:
# import math
# import pandas as pd
# from sklearn.linear_model import Ridge
#
# def get_model(data):
#     y = data['days'].dt.total_seconds() / 60
#     X = data.drop(columns='days')
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#     model = Ridge().fit(X_train, y_train)
#
#     y_pred = model.predict(X_test)
#     acc = mean_absolute_error(y_pred, y_test)
#     coef = model.coef_
#     print("Acc:", acc)
#     print("Coefs:", coef)
#
# if __name__ == "__main__":
#     interested = pd.read_csv("data.csv")
#     get_model(interested)

# %% [markdown]
# wrong code - wrong import of a library

# %%
data.loc[15, "correct_code"] = False

# %%
show_data(data.iloc[16])
# Out:
# 	Prefix:
# '''Filter'''
# import numpy as np
#
# def get_center(kernel):
#     '''Function that gets the center of the kernel'''
#     if kernel.shape[0] % 2 == 1 and kernel.shape[1] % 2 == 1:
#         return [kernel.shape[0]//2, kernel.shape[1]//2]
#     return [0, 0]
#
#
# def get_padding(center, kernel):
#     '''Gets number of zeros to be padded in each direction'''
#     if center == [0,0]:
#         return ((1,1),(1,1))
#     return (center[0], kernel.shape[0]-1-center[0]), (center[1], kernel.shape[1]-1-center[1])
#
#
# def convolve(array, kernel):
#     '''Applies convolution to a array'''
#     center = get_center(kernel)
#     padding = get_padding(center, kernel)
#     pad_image = np.pad(array, padding)
#     sha = (array.shape[0], array.shape[1], kernel.shape[0], kernel.shape[1])
#     stride = np.lib.stride_tricks.as_strided(pad_image, shape=sha, strides=pad_image.strides*2)
#     return np.sum(stride * kernel, axis=(2, 3))
#
#
# ...

# %% [markdown]
# correct code - convolving red channel

# %%
data.loc[16, "correct_code"] = True

# %%
show_data(data.iloc[17])
# Out:
# 	Prefix:
# '''Filter'''
# import numpy as np
#
#
# 	Fill here
# 	Actual code:
# def get_center(kernel):
# 	Generated code:
# nan
#
# Suffix:
#     '''Function that gets the center of the kernel'''
#     if kernel.shape[0] % 2 == 1 and kernel.shape[1] % 2 == 1:
#         return [kernel.shape[0]//2, kernel.shape[1]//2]
#     return [0, 0]
#
#
# def get_padding(center, kernel):
#     '''Gets number of zeros to be padded in each direction'''
#     if center == [0,0]:
#         return ((1,1),(1,1))
#     return (center[0], kernel.shape[0]-1-center[0]), (center[1], kernel.shape[1]-1-center[1])
#
#
# def convolve(array, kernel):
#     '''Applies convolution to a array'''
#     center = get_center(kernel)
#     padding = get_padding(center, kernel)
#     pad_image = np.pad(array, padding)
#     sha = (array.shape[0], array.shape[1], kernel.shape[0], kernel.shape[1])
#     stride = np.lib.stride_tricks.as_strided(pad_image, shape=sha, strides=pad_image.strides*2)
# ...

# %% [markdown]
# wrong code - start of a function definition not generated

# %%
data.loc[17, "correct_code"] = False

# %%
show_data(data.iloc[18])
# Out:
# 	Prefix:
# '''Filter'''
# import numpy as np
#
# def get_center(kernel):
#     '''Function that gets the center of the kernel'''
#     if kernel.shape[0] % 2 == 1 and kernel.shape[1] % 2 == 1:
#         return [kernel.shape[0]//2, kernel.shape[1]//2]
#     return [0, 0]
#
#
# def get_padding(center, kernel):
#     '''Gets number of zeros to be padded in each direction'''
#     if center == [0,0]:
#         return ((1,1),(1,1))
#     return (center[0], kernel.shape[0]-1-center[0]), (center[1], kernel.shape[1]-1-center[1])
#
#
# def convolve(array, kernel):
#     '''Applies convolution to a array'''
#     center = get_center(kernel)
#     padding = get_padding(center, kernel)
#     pad_image = np.pad(array, padding)
#     sha = (array.shape[0], array.shape[1], kernel.shape[0], kernel.shape[1])
#     stride = np.lib.stride_tricks.as_strided(pad_image, shape=sha, strides=pad_image.strides*2)
#     return np.sum(stride * kernel, axis=(2, 3))
#
#
# ...

# %% [markdown]
# correct code - return from a function

# %%
data.loc[18, "correct_code"] = True

# %%
show_data(data.iloc[19])
# Out:
# 	Prefix:
# '''Filter'''
# import numpy as np
#
# def get_center(kernel):
#     '''Function that gets the center of the kernel'''
#     if kernel.shape[0] % 2 == 1 and kernel.shape[1] % 2 == 1:
#         return [kernel.shape[0]//2, kernel.shape[1]//2]
#     return [0, 0]
#
#
#
# 	Fill here
# 	Actual code:
# def get_padding(center, kernel):
# 	Generated code:
# def get_padding(center, kernel):
#
# Suffix:
#     '''Gets number of zeros to be padded in each direction'''
#     if center == [0,0]:
#         return ((1,1),(1,1))
#     return (center[0], kernel.shape[0]-1-center[0]), (center[1], kernel.shape[1]-1-center[1])
#
#
# def convolve(array, kernel):
#     '''Applies convolution to a array'''
#     center = get_center(kernel)
#     padding = get_padding(center, kernel)
#     pad_image = np.pad(array, padding)
#     sha = (array.shape[0], array.shape[1], kernel.shape[0], kernel.shape[1])
#     stride = np.lib.stride_tricks.as_strided(pad_image, shape=sha, strides=pad_image.strides*2)
# ...

# %% [markdown]
# correct code - correct function definition

# %%
data.loc[19, "correct_code"] = True

# %%
show_data(data.iloc[20])
# Out:
# 	Prefix:
# '''Filter'''
# import numpy as np
#
# def get_center(kernel):
#     '''Function that gets the center of the kernel'''
#     if kernel.shape[0] % 2 == 1 and kernel.shape[1] % 2 == 1:
#         return [kernel.shape[0]//2, kernel.shape[1]//2]
#     return [0, 0]
#
#
# def get_padding(center, kernel):
#     '''Gets number of zeros to be padded in each direction'''
#     if center == [0,0]:
#         return ((1,1),(1,1))
#     return (center[0], kernel.shape[0]-1-center[0]), (center[1], kernel.shape[1]-1-center[1])
#
# 	Fill here
# 	Actual code:
# nan
# 	Generated code:
# nan
#
# Suffix:
#
# def convolve(array, kernel):
#     '''Applies convolution to a array'''
#     center = get_center(kernel)
#     padding = get_padding(center, kernel)
#     pad_image = np.pad(array, padding)
#     sha = (array.shape[0], array.shape[1], kernel.shape[0], kernel.shape[1])
#     stride = np.lib.stride_tricks.as_strided(pad_image, shape=sha, strides=pad_image.strides*2)
# ...

# %% [markdown]
# correct code - empty line

# %%
data.loc[20, "correct_code"] = True

# %%
show_data(data.iloc[21])
# Out:
# 	Prefix:
# '''Filter'''
# import numpy as np
#
# def get_center(kernel):
#     '''Function that gets the center of the kernel'''
#     if kernel.shape[0] % 2 == 1 and kernel.shape[1] % 2 == 1:
#         return [kernel.shape[0]//2, kernel.shape[1]//2]
#     return [0, 0]
#
#
# def get_padding(center, kernel):
#     '''Gets number of zeros to be padded in each direction'''
#     if center == [0,0]:
#         return ((1,1),(1,1))
#     return (center[0], kernel.shape[0]-1-center[0]), (center[1], kernel.shape[1]-1-center[1])
#
#
# def convolve(array, kernel):
#     '''Applies convolution to a array'''
#     center = get_center(kernel)
#     padding = get_padding(center, kernel)
#     pad_image = np.pad(array, padding)
#     sha = (array.shape[0], array.shape[1], kernel.shape[0], kernel.shape[1])
#     stride = np.lib.stride_tricks.as_strided(pad_image, shape=sha, strides=pad_image.strides*2)
#     return np.sum(stride * kernel, axis=(2, 3))
#
#
# ...

# %% [markdown]
# wrong code - it is not correct, but the generated code does not change anything

# %%
data.loc[21, "correct_code"] = True

# %%
show_data(data.iloc[22])
# Out:
# 	Prefix:
# '''Filter'''
# import numpy as np
#
# def get_center(kernel):
#     '''Function that gets the center of the kernel'''
#     if kernel.shape[0] % 2 == 1 and kernel.shape[1] % 2 == 1:
#         return [kernel.shape[0]//2, kernel.shape[1]//2]
#     return [0, 0]
#
#
# def get_padding(center, kernel):
#     '''Gets number of zeros to be padded in each direction'''
#     if center == [0,0]:
#         return ((1,1),(1,1))
#     return (center[0], kernel.shape[0]-1-center[0]), (center[1], kernel.shape[1]-1-center[1])
#
#
# def convolve(array, kernel):
#     '''Applies convolution to a array'''
#     center = get_center(kernel)
#     padding = get_padding(center, kernel)
#     pad_image = np.pad(array, padding)
#     sha = (array.shape[0], array.shape[1], kernel.shape[0], kernel.shape[1])
#     stride = np.lib.stride_tricks.as_strided(pad_image, shape=sha, strides=pad_image.strides*2)
#     return np.sum(stride * kernel, axis=(2, 3))
#
#
# ...

# %% [markdown]
# correct code - channel convolution

# %%
data.loc[22, "correct_code"] = True

# %%
show_data(data.iloc[23])
# Out:
# 	Prefix:
# '''Filter'''
# import numpy as np
#
# def get_center(kernel):
#     '''Function that gets the center of the kernel'''
#     if kernel.shape[0] % 2 == 1 and kernel.shape[1] % 2 == 1:
#         return [kernel.shape[0]//2, kernel.shape[1]//2]
#     return [0, 0]
#
#
# def get_padding(center, kernel):
#     '''Gets number of zeros to be padded in each direction'''
#     if center == [0,0]:
#         return ((1,1),(1,1))
#     return (center[0], kernel.shape[0]-1-center[0]), (center[1], kernel.shape[1]-1-center[1])
#
#
# def convolve(array, kernel):
#     '''Applies convolution to a array'''
#     center = get_center(kernel)
#     padding = get_padding(center, kernel)
#     pad_image = np.pad(array, padding)
#     sha = (array.shape[0], array.shape[1], kernel.shape[0], kernel.shape[1])
#     stride = np.lib.stride_tricks.as_strided(pad_image, shape=sha, strides=pad_image.strides*2)
#     return np.sum(stride * kernel, axis=(2, 3))
#
#
# ...

# %% [markdown]
# wrong code - performing convolution twice insted of once

# %%
data.loc[23, "correct_code"] = False

# %%
show_data(data.iloc[24])
# Out:
# 	Prefix:
# from position import Coordinates
# from figure import Figure
# from moves import filter_moves, get_score
# import math
#
#
# def minimax(board, color, depth, alpha, beta, maximize):
#     # with fewer figures depth should be higher todo
#     best_fig = Figure()
#     best_move = (Coordinates(-1, -1), False)
#
#     # if reached the selected depth, blacks score will be returned
#     if depth == 0:
#         return get_score(board, "black"), (best_fig, best_move)
#
#     if color == "white":
#         opponent_color = "black"
#
# 	Fill here
# 	Actual code:
#     else:
# 	Generated code:
#         opponent_color = "white"
#
# Suffix:
#         opponent_color = "white"
#
#     if maximize:
#         best_score = -math.inf
#     else:
#         best_score = math.inf
#
#     for x in range(8):
#         for y in range(8):
#             if board[x][y].get_type() != "figure" and board[x][y].get_color() == color:
#                 # figure has eligible moves that can be played
# ...

# %% [markdown]
# wrong code - missing else

# %%
data.loc[24, "correct_code"] = False

# %%
show_data(data.iloc[25])
# Out:
# 	Prefix:
# from position import Coordinates
# from figure import Figure
#
# 	Fill here
# 	Actual code:
# from moves import filter_moves, get_score
# 	Generated code:
# from filter_moves <|endoftext|>
#
# Suffix:
# import math
#
#
# def minimax(board, color, depth, alpha, beta, maximize):
#     # with fewer figures depth should be higher todo
#     best_fig = Figure()
#     best_move = (Coordinates(-1, -1), False)
#
#     # if reached the selected depth, blacks score will be returned
#     if depth == 0:
#         return get_score(board, "black"), (best_fig, best_move)
#
#     if color == "white":
#         opponent_color = "black"
#     else:
#         opponent_color = "white"
#
#     if maximize:
#         best_score = -math.inf
#     else:
#         best_score = math.inf
#
#     for x in range(8):
#         for y in range(8):
#             if board[x][y].get_type() != "figure" and board[x][y].get_color() == color:
#                 # figure has eligible moves that can be played
# ...

# %% [markdown]
# wrong code - incorrect import

# %%
data.loc[25, "correct_code"] = False

# %%
show_data(data.iloc[26])
# Out:
# 	Prefix:
# from position import Coordinates
# from figure import Figure
# from moves import filter_moves, get_score
# import math
#
#
# def minimax(board, color, depth, alpha, beta, maximize):
#     # with fewer figures depth should be higher todo
#
# 	Fill here
# 	Actual code:
#     best_fig = Figure()
# 	Generated code:
#     if depth == 0:
#
# Suffix:
#     best_move = (Coordinates(-1, -1), False)
#
#     # if reached the selected depth, blacks score will be returned
#     if depth == 0:
#         return get_score(board, "black"), (best_fig, best_move)
#
#     if color == "white":
#         opponent_color = "black"
#     else:
#         opponent_color = "white"
#
#     if maximize:
#         best_score = -math.inf
#     else:
#         best_score = math.inf
#
#     for x in range(8):
#         for y in range(8):
#             if board[x][y].get_type() != "figure" and board[x][y].get_color() == color:
#                 # figure has eligible moves that can be played
# ...

# %% [markdown]
# wrong code

# %%
data.loc[26, "correct_code"] = False

# %%
show_data(data.iloc[27])
# Out:
# 	Prefix:
# from position import Coordinates
# from figure import Figure
# from moves import filter_moves, get_score
# import math
#
#
# def minimax(board, color, depth, alpha, beta, maximize):
#     # with fewer figures depth should be higher todo
#     best_fig = Figure()
#     best_move = (Coordinates(-1, -1), False)
#
#     # if reached the selected depth, blacks score will be returned
#     if depth == 0:
#         return get_score(board, "black"), (best_fig, best_move)
#
#     if color == "white":
#         opponent_color = "black"
#     else:
#         opponent_color = "white"
#
#     if maximize:
#         best_score = -math.inf
#     else:
#         best_score = math.inf
#
#     for x in range(8):
#         for y in range(8):
#             if board[x][y].get_type() != "figure" and board[x][y].get_color() == color:
#                 # figure has eligible moves that can be played
#                 moves = board[x][y].get_moves(board)
#                 figure = board[x][y]
# ...

# %% [markdown]
# wrong code - incorrect if statement

# %%
data.loc[27, "correct_code"] = False

# %%
show_data(data.iloc[28])
# Out:
# 	Prefix:
# from position import Coordinates
# from figure import Figure
# from moves import filter_moves, get_score
# import math
#
#
# def minimax(board, color, depth, alpha, beta, maximize):
#     # with fewer figures depth should be higher todo
#     best_fig = Figure()
#     best_move = (Coordinates(-1, -1), False)
#
#
# 	Fill here
# 	Actual code:
#     # if reached the selected depth, blacks score will be returned
# 	Generated code:
#     for x in range(8):
#
# Suffix:
#     if depth == 0:
#         return get_score(board, "black"), (best_fig, best_move)
#
#     if color == "white":
#         opponent_color = "black"
#     else:
#         opponent_color = "white"
#
#     if maximize:
#         best_score = -math.inf
#     else:
#         best_score = math.inf
#
#     for x in range(8):
#         for y in range(8):
#             if board[x][y].get_type() != "figure" and board[x][y].get_color() == color:
#                 # figure has eligible moves that can be played
# ...

# %% [markdown]
# wrong code - no line or comment should have been generated

# %%
data.loc[28, "correct_code"] = False

# %%
show_data(data.iloc[29])
# Out:
# 	Prefix:
# from position import Coordinates
# from figure import Figure
# from moves import filter_moves, get_score
# import math
#
#
# def minimax(board, color, depth, alpha, beta, maximize):
#     # with fewer figures depth should be higher todo
#     best_fig = Figure()
#     best_move = (Coordinates(-1, -1), False)
#
#     # if reached the selected depth, blacks score will be returned
#     if depth == 0:
#         return get_score(board, "black"), (best_fig, best_move)
#
#     if color == "white":
#         opponent_color = "black"
#     else:
#
# 	Fill here
# 	Actual code:
#         opponent_color = "white"
# 	Generated code:
#         opponent_color = color
#
# Suffix:
#
#     if maximize:
#         best_score = -math.inf
#     else:
#         best_score = math.inf
#
#     for x in range(8):
#         for y in range(8):
#             if board[x][y].get_type() != "figure" and board[x][y].get_color() == color:
#                 # figure has eligible moves that can be played
# ...

# %% [markdown]
# wrong code - incorrect color assignment

# %%
data.loc[29, "correct_code"] = False

# %%
show_data(data.iloc[30])
# Out:
# 	Prefix:
# from position import Coordinates
# from figure import Figure
# from moves import filter_moves, get_score
# import math
#
#
# def minimax(board, color, depth, alpha, beta, maximize):
#     # with fewer figures depth should be higher todo
#     best_fig = Figure()
#     best_move = (Coordinates(-1, -1), False)
#
#     # if reached the selected depth, blacks score will be returned
#     if depth == 0:
#         return get_score(board, "black"), (best_fig, best_move)
#
#     if color == "white":
#         opponent_color = "black"
#     else:
#         opponent_color = "white"
#
#     if maximize:
#         best_score = -math.inf
#     else:
#         best_score = math.inf
#
#     for x in range(8):
#         for y in range(8):
#             if board[x][y].get_type() != "figure" and board[x][y].get_color() == color:
#                 # figure has eligible moves that can be played
#                 moves = board[x][y].get_moves(board)
#                 figure = board[x][y]
# ...

# %% [markdown]
# wrong code - no line

# %%
data.loc[30, "correct_code"] = False

# %%
show_data(data.iloc[31])
# Out:
# 	Prefix:
# from position import Coordinates
# from figure import Figure
# from moves import filter_moves, get_score
# import math
#
#
# def minimax(board, color, depth, alpha, beta, maximize):
#     # with fewer figures depth should be higher todo
#     best_fig = Figure()
#     best_move = (Coordinates(-1, -1), False)
#
#     # if reached the selected depth, blacks score will be returned
#     if depth == 0:
#         return get_score(board, "black"), (best_fig, best_move)
#
#     if color == "white":
#         opponent_color = "black"
#     else:
#         opponent_color = "white"
#
#     if maximize:
#         best_score = -math.inf
#     else:
#         best_score = math.inf
#
#     for x in range(8):
#         for y in range(8):
#             if board[x][y].get_type() != "figure" and board[x][y].get_color() == color:
#                 # figure has eligible moves that can be played
#                 moves = board[x][y].get_moves(board)
#                 figure = board[x][y]
# ...

# %% [markdown]
# wrong code - empty line

# %%
data.loc[31, "correct_code"] = False

# %% [markdown]
# ### Summary

# %%
print_results(data)

hand_label = data['correct_code'].value_counts()
print(f"Hand label:\n{hand_label.to_string(index=True, header=False)}")
print(f"{(hand_label[True]/(hand_label[True] + hand_label[False]))*100} %")

data.to_csv("data.csv", index=False)
# Out:
# CHRF:
# 26.57 %
#
# Correct syntax:
# True     16
# False    11
# nan       5
# 60.71 %
#
# Exact match:
# False    22
# nan       5
# True      5
# 21.43 %
#
# rougeL:
# 27.57 %
#
# Hand label:
# False    20
# True     12
# 37.5 %

# %% [markdown]
# ### Result
#
# The results from testing the Tiny Starcoder model for code completion on a dataset containing empty lines intended for completion indicate that its performance is limited. Both CHRF and ROUGE scores reflect an accuracy of around 27%, suggesting room for improvement. On a positive note, the model achieves a syntax accuracy of over 60%, which shows that it can generally maintain correct syntax. However, only 37% of examples are fully completed as intended.
#
# For higher performance, models like the full-size Starcoder or CodeLlama would be preferable, though they are too computationally demanding to run effectively on my current setup.
